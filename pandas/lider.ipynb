# %%
import pandas as pd

# %%
df = pd.read_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv")
df.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
#   Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)
# 0                                            7202.00
# 1                                               8602
# 2                                               8402
# 3                                            4802.00
# 4                                               5402

# %%
def sumar_digitos(x):
    x_str = str(x)
    sum=0
    for i in x_str:
      sum+= int(i)
    return sum

def crear_funcion(n):
    def f(x):
        return n * (x**2) + 2*x + 23
    return f

def evaluar_funcion1(n):
  f=crear_funcion(n)
  return (f(105)-f(100))/5

df["n"]= df["Número de documento"].apply(sumar_digitos)
df["Punto 1"] = df["n"].apply(evaluar_funcion1).round(2)
def calificar1(x):
  return 5*(x[1]== x["Punto 1"])

df["Calificacion 1"] = df.apply(calificar1 , axis=1)
# Out:
# /tmp/ipykernel_6602/2109980600.py:20: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return 5*(x[1]== x["Punto 1"])

# %%
df.head()
# Out:
#    Número de documento  \
# 0           1021674384
# 1           1028481694
# 2           1012976628
# 3           1103500518
# 4           1141316451
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 105 unidades (Poner dos decimales)  \
# 0                                             7382.0
# 1                                             8817.0
# 2                                             8612.0
# 3                                             4922.0
# 4                                             5537.0
#
#    Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nHallar el costo promedio de producir  de 100 a 101 unidades (Poner dos decimales)\n  \
# 0                                             7238.0
# 1                                             8645.0
# 2                                             8444.0
# 3                                             4826.0
# 4                                             5429.0
#
#   Sea la función de costo C(x) = n*x^2 + 2*x + 23. \nUsar el costo marginal para aproximar el costo promedio entre x= 100 y x =101 (Poner dos decimales)  \
# 0                                            7202.00
# 1                                               8602
# 2                                               8402
# 3                                            4802.00
# 4                                               5402
#
#     n  Punto 1  Calificacion 1
# 0  36   7382.0               5
# 1  43   8817.0               5
# 2  42   8612.0               5
# 3  24   4922.0               5
# 4  27   5537.0               5

# %%
df_original = pd.read_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv")

# %%
df_original["Punto 1"] = df["Punto 1"]
df_original["Calificacion 1"] = df["Calificacion 1"]

# %%
df_original.to_csv("Quiz Cálculo 1- Gobierno 22 de Octubre(1-18).csv", index=False)
